# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
df = pd.read_csv("drug_side_effects_100k_dataset.csv")

# %%
df.head()
# Out:
#   patient_id  age  gender   country     drug_name  dosage_mg   side_effect  \
# 0  PT-100000   56  Female       USA  Atorvastatin         25   Muscle Pain
# 1  PT-100001   45    Male       USA    Sertraline          5     Dry Mouth
# 2  PT-100002   76  Female  Pakistan       Insulin         25  Hypoglycemia
# 3  PT-100003   61  Female       USA   Paracetamol         20          Rash
# 4  PT-100004   39  Female     India    Amlodipine          5     Dizziness
#
#    severity     outcome report_date treatment_start_date chronic_condition  \
# 0  Moderate  Recovering  2021-12-08           2021-11-23      Hypertension
# 1      Mild   Recovered  2023-02-10           2023-02-04      Hypertension
# 2      Mild  Recovering  2021-07-30           2021-07-01     Heart Disease
# 3  Moderate   Recovered  2025-05-02           2025-04-18            Asthma
# 4      Mild   Recovered  2025-05-23           2025-04-06               NaN
#
#   smoker alcohol_use hospitalized  recovery_days
# ...

# %%
df.shape
# Out:
# (100000, 16)

# %%
df['drug_name'].unique()
# Out:
# array(['Atorvastatin', 'Sertraline', 'Insulin', 'Paracetamol',
#        'Amlodipine', 'Amoxicillin', 'Ibuprofen', 'Metformin',
#        'Lisinopril', 'Omeprazole'], dtype=object)

# %%
df['country'].unique()
# Out:
# array(['USA', 'Pakistan', 'India', 'Australia', 'UK', 'Canada', 'Germany'],
#       dtype=object)

# %%
df['side_effect'].unique()
# Out:
# array(['Muscle Pain', 'Dry Mouth', 'Hypoglycemia', 'Rash', 'Dizziness',
#        'Nausea', 'Sweating', 'Swelling', 'Anxiety', 'Stomach Pain',
#        'Abdominal Pain', 'Headache', 'Fatigue', 'Weight Gain',
#        'Heartburn', 'Diarrhea', 'Dry Cough', 'Constipation',
#        'Liver Toxicity', 'Palpitations', 'Insomnia'], dtype=object)

# %%
df["chronic_condition"].unique()
# Out:
# array(['Hypertension', 'Heart Disease', 'Asthma', nan, 'Diabetes',
#        'Kidney Disease'], dtype=object)

# %%
df["outcome"].unique()
# Out:
# array(['Recovering', 'Recovered', 'Hospitalized', 'Fatal'], dtype=object)

# %%
df["severity"].unique()
# Out:
# array(['Moderate', 'Mild', 'Severe'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   patient_id            100000 non-null  object
#  1   age                   100000 non-null  int64
#  2   gender                100000 non-null  object
#  3   country               100000 non-null  object
#  4   drug_name             100000 non-null  object
#  5   dosage_mg             100000 non-null  int64
#  6   side_effect           100000 non-null  object
#  7   severity              100000 non-null  object
#  8   outcome               100000 non-null  object
#  9   report_date           100000 non-null  object
#  10  treatment_start_date  100000 non-null  object
#  11  chronic_condition     83257 non-null   object
#  12  smoker                100000 non-null  object
#  13  alcohol_use           66635 non-null   object
# ...

# %%
df.describe()
# Out:
#                  age      dosage_mg  recovery_days
# count  100000.000000  100000.000000   88262.000000
# mean       47.781740     119.896250      23.569996
# std        17.055106     162.249791      12.690178
# min        18.000000       5.000000       2.000000
# 25%        35.000000      10.000000      13.000000
# 50%        47.000000      25.000000      24.000000
# 75%        60.000000     250.000000      35.000000
# max        90.000000     500.000000      45.000000

# %%
df.isnull().sum()
# Out:
# patient_id                  0
# age                         0
# gender                      0
# country                     0
# drug_name                   0
# dosage_mg                   0
# side_effect                 0
# severity                    0
# outcome                     0
# report_date                 0
# treatment_start_date        0
# chronic_condition       16743
# smoker                      0
# alcohol_use             33365
# hospitalized                0
# recovery_days           11738
# dtype: int64

# %%
df.drop(["patient_id", "report_date", "treatment_start_date"], axis=1, inplace=True)

# %%
df.head()
# Out:
#    age  gender   country     drug_name  dosage_mg   side_effect  severity  \
# 0   56  Female       USA  Atorvastatin         25   Muscle Pain  Moderate
# 1   45    Male       USA    Sertraline          5     Dry Mouth      Mild
# 2   76  Female  Pakistan       Insulin         25  Hypoglycemia      Mild
# 3   61  Female       USA   Paracetamol         20          Rash  Moderate
# 4   39  Female     India    Amlodipine          5     Dizziness      Mild
#
#       outcome chronic_condition smoker alcohol_use hospitalized  recovery_days
# 0  Recovering      Hypertension    Yes    Frequent           No           36.0
# 1   Recovered      Hypertension    Yes    Frequent           No           40.0
# 2  Recovering     Heart Disease     No         NaN           No           12.0
# 3   Recovered            Asthma    Yes         NaN           No           26.0
# 4   Recovered               NaN    Yes  Occasional           No            7.0

# %%
df.duplicated().sum()
# Out:
# np.int64(9)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
